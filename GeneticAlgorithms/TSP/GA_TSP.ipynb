# %% [markdown]
# ### Generating graph

# %%
import random
def generateGraph(nodes, chance_for_zero):
    net = {}
    mat = [[0 for _ in range(nodes)] for _ in range(nodes)]
    distMat = [[0 for _ in range(nodes)] for _ in range(nodes)]
    for i in range(nodes):
        for j in range(nodes):
            if i == j:
                mat[i][j] = 0
                distMat[i][j] = 0
            else:
                p = random.random()
                if p > chance_for_zero:
                    # mat[i][j] = random.randint(1, 1000)
                    mat[i][j] = 1
                    distMat[i][j] = mat[i][j]
                else:
                    mat[i][j] = 0
                    distMat[i][j] = 2000
    net['noNodes'] = nodes
    net['noEdges'] = nodes * (nodes - 1)
    net['mat'] = mat
    net['distMat'] = distMat
    net['type'] = 'generated'
    return net

# %% [markdown]
# ### GML Read

# %%
#readFromGML
import networkx as nx
import numpy as np
# 
def readFromGML(filePath):
    G = nx.read_gml(filePath, label='id')
    G = nx.convert_node_labels_to_integers(G, first_label=0, ordering='default', label_attribute=None)

    adj_list = G.adj
    #print(adj_list)
    net = {}
    net['adjList'] = adj_list
    net['noNodes'] = G.number_of_nodes()
    net['noEdges'] = G.number_of_edges()
    net['nodes'] = list(G.nodes())
    net['edges'] = G.edges()
    A = nx.to_numpy_matrix(G)

    net['mat'] = A
    net['distMat'] = [[0 for _ in range(net['noNodes'])] for _ in range(net['noNodes'])]
    for i in range(net['noNodes']):
        for j in range(net['noNodes']):
            if net['mat'][i,j] == 0.0:
                net['distMat'][i][j] = 2000
            else:
                net['distMat'][i][j] = net['mat'][i,j]

    deg = dict(G.degree())
    net['degrees'] = np.array(list(deg.values()))
    
    return net

# net = readFromGML('data\\real\\krebs\\krebs.gml')
#print(net['mat'])
#print(net['mat'])
# print(net['mat'][2,1])

# %% [markdown]
# ### File Read

# %%
import networkx as nx
import math
class Coord:
    def __init__(self, node, x, y):
        self.__node = node
        self.__x = x
        self.__y = y

    @property
    def x(self):
        return self.__x
    @property
    def y(self):
        return self.__y

def readFromFile(filePath):
    net = {}
    G = nx.Graph()
    f = open(filePath, "r")
    n = 100000
    # mat = [[0 for _ in range(n)] for _ in range(n)]
    net['noNodes'] = n
    net['type'] = 'file'
    # net['distMat'] = [[0 for _ in range(n)] for _ in range(n)]
    print('initialized variables')
    nodes = []
    cnt = 0
    for line in f:
        coords = line.strip().split(" ")
        i = int(coords[0])
        print(f'at line {i}')
        x = int(coords[1])
        y = int(coords[2])
        coord = Coord(i, x, y)
        nodes.append(coord)
    # print('finished reading')
    # for i in range(n):
    #     for j in range(n):
    #         if i == j:
    #             mat[i][j] = 0
    #         mat[i][j] = calc_euclidian_distance(nodes[i], nodes[j])
    #         if mat[i][j] == 0:
    #             net['distMat'][i][j] = 2000
    #         else:
    #             net['distMat'][i][j] = mat[i][j]
    print('finished distance matrix')
    net['nodes'] = nodes
    # !net['noEdges'] = cnt + 1
    # net['adjList'] = G.adj
    return net


# readFromFile("data\\tsp_dataset\\five_d.txt")

# %% [markdown]
# ### Plotting

# %%
#plotNetwork
import matplotlib.pyplot as plt 
import matplotlib 
import warnings 
import networkx as nx
import numpy as np

# plot a network 
def plotNetwork(network, path):
    np.random.seed(123) #to freeze the graph's view (networks uses a random view)
    #for chr in paths:
    if network['type'] != 'file':
        A=np.matrix(network['mat'])
        G=nx.from_numpy_matrix(A)
        node_colors = np.zeros(G.number_of_nodes())
        i = 0
        while i < len(path):
            node_colors[path[i]] = 1
            i += 1
    #print(f'A = {A}')
    #print(f'matrix', network['mat'])
    #print(f'dist matrix', network['distMat'])
    #print(f'G.edges:{G.edges()}')

    # for path in paths:
        
    edges = set()
    i = 1
    # newGraph = nx.Graph()
    # newGraph.add_edge(network['source'], path[0])
    edges.add((network['source'], path[0]))
    
    while i < len(path):
        # newGraph.add_edge(path[i - 1], path[i])
        edges.add((path[i - 1], path[i]))
        i += 1
    # newGraph.add_edge(path[i], network['source'])
    edges.add((path[i - 1], network['source']))
    
    if network['type'] != 'file':
        edge_colors = np.zeros(G.number_of_edges())
        cnt = 0
        for i, edge in enumerate(G.edges()):
            if edge in edges or (edge[1], edge[0]) in edges:
                cnt += 1
                edge_colors[i] = 1
        percent = cnt / network['noNodes']
        print(f'% of edges: {percent}')
        colors = ['red' if val else 'black' for val in edge_colors]

    if network['noNodes'] <= 500:
        pos = nx.spring_layout(G)  # compute graph layout
        plt.figure(figsize=(10, 10))  # image is 8 x 8 inches 
        labels = {i: i for i in G.nodes()}
        # nx.draw_networkx_nodes(G, pos, node_size=80, cmap=plt.cm.RdYlBu, node_color = communities)
        nx.draw_networkx_nodes(G, pos, node_size=80, cmap=plt.cm.RdYlBu)
        nx.draw_networkx_edges(G, pos, alpha=0.5, edge_color=colors)
        nx.draw_networkx_labels(G, pos)

        # posNewGraph = nx.spring_layout(newGraph)
        # nx.draw_networkx_nodes(newGraph, posNewGraph, node_size=80, cmap=plt.cm.RdYlBu)
        # nx.draw_networkx_edges(G, pos, alpha=0.5)
        # nx.draw_networkx_labels(G, pos)

        # plt.title(titleGML)
        plt.show(G)

# %% [markdown]
# ### Fitness function
# Sum of all weights on the path, where a path entry is represented by {u, v, w}, meaning there is an edge between u and v of weight w

# %%
def calc_euclidian_distance(coord1, coord2):
    return math.sqrt((coord2.x - coord1.x) ** 2 + (coord2.y - coord1.y) ** 2)

def sumWeights(path, network):

    source = network['source']
    V = network['noNodes'] - 1
    if network['type'] != 'file':
        adjMatrix = network['distMat']
        sum = adjMatrix[source][path[0]]
        for i in range(1, V - 1):
            #print(adjMatrix[i, i+1])
            sum += adjMatrix[path[i]][path[i + 1]]
            # TODO: if we got weights, atm doing without weights
            # TODO: sum += weight
            # !sum += 1
        sum += adjMatrix[path[V - 1]][source]
        #print(sum)
        return sum
    else:
        nodes = network['nodes']
        sum = calc_euclidian_distance(nodes[source], nodes[path[0]])
        for i in range(1, V - 1):
            sum += calc_euclidian_distance(nodes[path[i]], nodes[path[i + 1]])
        sum += calc_euclidian_distance(nodes[path[V - 1]], nodes[source])
        return sum
    # return 1 / sum

# %% [markdown]
# ### Chromosome definition
# <strong>Initialization</strong> - Permutation of all nodes except the source node<br/>
# <strong>Selection</strong> - First best 2 individuals <br/>
# <strong>Crossover</strong> - Order 1 crossover (OX1) / Partially-mapped crossover<br/>
# <strong>Mutation</strong> - Swap mutation<br/>
# <strong>Replacement</strong> - If more fit, will replace the worst in that generation<br/>
# <strong>Termination condition</strong> - Number of generations<br/>
# <a href="https://towardsdatascience.com/evolution-of-a-salesman-a-complete-genetic-algorithm-tutorial-for-python-6fe5d2b3ca35">credit

# %%
import random
import numpy as np

class Chromosome:
    def __init__(self, problParam):
        self.__problParam = problParam
        self.__fitness = 0.0
        #initiating a ndarray of dimension 1 with -1
        self.__repres = np.full((self.__problParam['network']['noNodes'] - 1, ), -1)


    @property
    def fitness(self):
        return self.__fitness
    
    @property
    def repres(self):
        return self.__repres
    
    @fitness.setter
    def fitness(self, fit = 0.0):
        self.__fitness = fit
    
    @repres.setter
    def repres(self, l = []):
        self.__repres = l
        
    def initPath(self):
        V = self.__problParam['network']['noNodes']
        # *array with values (0, 1, .. V - 1)
        arr = np.arange(V)
        # *shuffling the array
        shuffled_arr = np.random.permutation(arr)
        # !filtering out using boolean indexing
        
        source = self.__problParam['source']
        self.__repres = shuffled_arr[shuffled_arr != source]
        #print(self.__repres)
        #print(self.__repres)
    
    def mutation(self):
        # *selecting 2 random indices 
        i, j = np.random.choice(self.__repres.size, size=2, replace=False)
        # *swapping their values
        self.__repres[i], self.__repres[j] = self.__repres[j], self.__repres[i]

    def order_1_crossover(self, c):
        V = self.__problParam['network']['noNodes'] - 1
        segment_index = random.randint(0, V // 2)
        #print(segment_index)
        segment_size = random.randint(1, V // 2)
       # print(segment_size)

        genes_segment_p1 = self.__repres[segment_index : segment_index + segment_size]
        genes_segment_p2 = c.repres[segment_index : segment_index + segment_size]

        offspring1 = Chromosome(self.__problParam)
        offspring2 = Chromosome(self.__problParam)

        offspring1.repres[segment_index : segment_index + segment_size] = genes_segment_p1
        offspring2.repres[segment_index : segment_index + segment_size] = genes_segment_p2

        negative_indices = np.where(offspring1.repres == -1)[0]
        negative_index = negative_indices[0]
        while negative_index < V:
            if negative_index == segment_index:
                negative_index += segment_size
            else:
                for i in range(V):
                    if negative_index == segment_index:
                        break
                    if c.repres[i] not in genes_segment_p1 and c.repres[i] not in offspring1.repres:
                        offspring1.repres[negative_index] = c.repres[i]
                        negative_index += 1

        negative_index = negative_indices[0]
        while negative_index < V:
            if negative_index == segment_index:
                negative_index += segment_size
            else:
                for i in range(V):
                    if negative_index == segment_index:
                        break
                    if self.__repres[i] not in genes_segment_p2 and self.__repres[i] not in offspring2.repres:
                        offspring2.repres[negative_index] = self.__repres[i]
                        negative_index += 1

        return offspring1, offspring2
    


    def partially_mapped_crossover(self, c):
        # *substracting 1 because of the source node outside of our permutations array
        V = self.__problParam['network']['noNodes'] - 1
        index = random.randint(0, V // 2)

        genes_from_parent1 = self.__repres[index : index + V // 2]
        genes_from_parent2 = c.repres[index : index + V // 2]

        # *initiating the offspring
        offspring1 = Chromosome(self.__problParam)
        offspring2 = Chromosome(self.__problParam)

        # *adding to their repre
        offspring1.repres[index : index + V // 2] = c.repres[index : index + V // 2]
        offspring2.repres[index : index + V // 2] = self.__repres[index : index + V // 2]

        # *array of indices there's -1 in the representation of the offsprings
        # *initially they will have -1's in the same places => we can choose arbitrarily which representation to evaluate
        negative_indices_in_repres = np.where(offspring1.repres == -1)[0]

        # ! applying the partially-mapped crossover algorithm for filling up the empty spaces 

        # *for offspring1
        for index in negative_indices_in_repres:
            gene_parent1 = self.__repres[index]
            while gene_parent1 in genes_from_parent2:
                index_gene_in_parent2 = np.where(genes_from_parent2 == gene_parent1)[0][0]
                gene_parent1 = genes_from_parent1[index_gene_in_parent2]
            offspring1.repres[index] = gene_parent1

        # *for offspring2
        for index in negative_indices_in_repres:
            gene_parent2 = c.repres[index]
            while gene_parent2 in genes_from_parent1:
                index_gene_in_parent1 = np.where(genes_from_parent1 == gene_parent2)[0][0]
                gene_parent2 = genes_from_parent2[index_gene_in_parent1]
            offspring2.repres[index] = gene_parent2
        
        return offspring1, offspring2

    def ordered_crossover(self, c):
        V = self.__problParam['network']['noNodes']
        # *filling offspring with -1
        offspring = Chromosome(self.__problParam)
        offspring.repres = np.full_like(self.__repres, -1)

        # *choosing random noSgements to copy from .self
        # *up to  (v - 1) / 2
        # ?maybe np.random.randint(1, (V - 1) // 2 + 1)
        noSegments = np.random.randint(1, V // 4)
        # *segment sizes
        k = 3
        # *choosing random V - 1 indices, then sorting them for convenience
        segment_indices = np.sort(np.random.choice(V - 1, size=noSegments, replace=False))
        # *list of tuples, where tuples are {segments, start_segment_index} to remember the position for offspring copy
        segments = [(self.__repres[segment_indices[i]:segment_indices[i] + k], segment_indices[i]) for i in range(noSegments - 1)]
        # !also appending the list of nodes not met in our segments
        # !segments.append((np.setdiff1d(self.__repres, np.concatenate(segments)), segment_indices[-1]))

        # *sorting by indices
        segments = sorted(segments, key = lambda x: x[1])

        # *copying the segments into the offspring
        for segment in segments:
            start = segment[1]
            end = start + len(segment[0])
            offspring.repres[start:end] = segment[0]

        # *filling in remaining slots from other chromosome: c
        index = 0
        while offspring.repres[index] != -1:
            index += 1
        for gene in c.repres:
            if gene not in self.__repres:
                offspring.repres[index] = gene
                index += 1

        return offspring        

    def evaluate(self):
        self.fitness = self.__problParam['function'](self.__repres, self.__problParam['network'])

# %% [markdown]
# ### Genetic algorithm

# %%
import heapq
import ipywidgets as widgets

class GA:
    def __init__(self, problParam = None):
        #self.__param = param
        self.__problParam = problParam
        self.__population = []

    @property
    def population(self):
        return self.__population

    def inititialization(self):
        print('Initializing')
        progressBar = widgets.IntProgress(min=1, max=self.__problParam['popSize'])
        display(progressBar)
        for chrCount in range(self.__problParam['popSize']):
            #print('initializare - at chr: ', chrCount)
            c = Chromosome(self.__problParam)
            c.initPath()
            #print(c.repres)
            #print('passed init path')
            self.__population.append(c)
            progressBar.value += 1

    def evaluation(self):
        for c in self.__population:
            c.fitness = self.__problParam['function'](c.repres, self.__problParam['network'])
            #print(c.fitness)

    def nextGeneration(self):
        fitness = lambda x: x.fitness
        #select the best 2 individuals
        # entries = heapq.nlargest(2, self.__population, key=fitness)
        entries = np.random.choice(len(self.__population), size=2, replace=False)
        #print(entries)
        p1 = self.__population[entries[0]]
        p2 = self.__population[entries[1]]
        #print(p1.repres, p2.repres)
        # *generating offspring through crossover and mutation
        # offspring = p1.ordered_crossover(p2)
        # print()
        # print(f'before crossover p1: {p1.repres}')
        # print(f'before crossover p2: {p2.repres}')
        # offspring1, offspring2 = p1.order_1_crossover(p2)
        offspring1, offspring2 = p1.partially_mapped_crossover(p2)
        # print(f'after crossover off1: {offspring1.repres}')
        # print(f'after crossover off2: {offspring2.repres}')
        offspring1.mutation()
        offspring2.mutation()
        # print(f'after mutation off1: {offspring1.repres}')
        # print(f'after mutation off2: {offspring2.repres}')
        # *evaluating the fitness of the new offspring
        offspring1.evaluate()
        offspring2.evaluate()
        
        # *getting the least fit individual
        # *sorting ascending > getting lowest fitness
        # ?worst_indices = sorted(range(len(self.__population)), key=lambda i:self.__population[i].fitness, reverse=True)[:1]
        worst_indices = sorted(range(len(self.__population)), key=lambda i:self.__population[i].fitness, reverse=True)[:1]
        chosen_offspring = offspring1
        if offspring2.fitness < offspring1.fitness:
            chosen_offspring = offspring2

        if chosen_offspring.fitness < self.__population[worst_indices[0]].fitness:
            self.__population[worst_indices[0]] = chosen_offspring
        
        # replaced1 = False
        # replaced2 = False
        # #we either replace first, or second offspring, if they are more fit
        # # ?if offspring1.fitness > self.__population[worst_indices[0]].fitness:
        # if offspring1.fitness < self.__population[worst_indices[0]].fitness:
        #     #we replaced first offspring
        #     self.__population[worst_indices[0]] = offspring1
        #     replaced1 = True
        # elif offspring2.fitness > self.__population[worst_indices[0]].fitness:
        #     #we replaced second offspring
        #     self.__population[worst_indices[0]] = offspring2
        #     replaced2 = True

        # #right now, either one of the offsprings has been replaced, we evaluate the other with the 2nd worst
        # if replaced1 == False and offspring1.fitness > self.__population[worst_indices[1]].fitness:
        #     #we didnt replace first offspring with the worst
        #     self.__population[worst_indices[1]] = offspring1
        #     replaced1 = True
        # elif replaced2 == False and offspring2.fitness > self.__population[worst_indices[1]].fitness:
        #     #we didnt replace second offspring with the worst
        #     self.__population[worst_indices[1]] = offspring2
        #     replaced2 = True

    def bestChromosome(self):
        best = self.__population[0]
        for c in self.__population:
            # ?if c.fitness > best.fitness:
            if c.fitness < best.fitness:
                best = c
        best_list = []
        for c in self.__population:
            if c.fitness == best.fitness:
                #print('found chr with best fitness')
                best_list.append(c)
        return best_list

# %% [markdown]
# ### Running the algorithm

# %%
#runningAlgorithm

import ipywidgets as widgets
import time
def applyGA(network, source, destination, iterations):
    network['source'] = source
    problParam = {'popSize': 50, 'network': network, 'source': source, 'destination': destination, 'function': sumWeights}
    #print('constructor')
    ga = GA(problParam)
    #print('initializare')
    ga.inititialization()
    # print('evaluare')
    ga.evaluation()
    #print('finished evaluare')

    print('Passing through generations')
    progressBar = widgets.IntProgress(min=1, max=iterations)
    display(progressBar)
    for _ in range(iterations):
        ga.nextGeneration()
        progressBar.value += 1
        time.sleep(0.01)
        # print(ga.bestChromosome()[0].repres)

    # for chr in ga.population:
    #     print(f'{chr.repres}, {chr.fitness}')

    best_list = ga.bestChromosome()
    unique_paths = []
    seen_paths = set()
    for path in best_list:
        path_repr = tuple(path.repres)
        if path_repr not in seen_paths:
            unique_paths.append(path)
            seen_paths.add(path_repr)
        
    # print(f'source = {source}, destination = {destination}')
    if network['type'] != 'file': 
        for path in unique_paths:
            #print('best chromosome')

            print(f'fitness: {path.fitness}, repres: {path.repres}')
            #print(f'nodes contained: {nodesContained(path.repres)}')
            plotNetwork(network, path=path.repres)
    else:
        print(f'fitness: {path.fitness}, repres: {path.repres}')
        f = open("mona-lisa-out.txt", "a")
        for path in unique_paths:
            for node in path.repres:
                f.write(str(node) + " ")
    
    # dijkstra_edges = Dijkstra(network['noNodes'], network['adjList'], source, destination)
    #print(dijkstra_edges)
    #print(len(dijkstra_edges))

def nodesContained(repres):
    nodes = set()
    for u, v, _ in repres:
        nodes.add(u)
        nodes.add(v)
    return len(nodes)

# network = readFromGML('data\\real\\graph.gml')
# network = readFromFile("data\\tsp_dataset\\five_d.txt")
# print('generating graph')
# network = generateGraph(nodes=5, chance_for_zero=0.5)
# print('generated graph')
# applyGA(network, source = 4, destination =4, iterations=30)
# print('generating graph')
# network = generateGraph(nodes=20, chance_for_zero=0.5)
# print('generated graph')
# applyGA(network, source = 4, destination =4, iterations=30)
# print('generating graph')
# network = generateGraph(nodes=600, chance_for_zero=0.5)
# print('generated graph')
# applyGA(network, source = 4, destination =4, iterations=30)
print('generating graph')
network = readFromFile('data\\tsp_dataset\\mona-lisa100K.tsp')
print('generated graph')
applyGA(network, source = 4, destination =4, iterations=10)
# Out:
# generating graph
# initialized variables
# at line 1
# at line 2
# at line 3
# at line 4
# at line 5
# at line 6
# at line 7
# at line 8
# at line 9
# at line 10
# at line 11
# at line 12
# at line 13
# at line 14
# at line 15
# at line 16
# at line 17
# at line 18
# at line 19
# at line 20
# at line 21
# at line 22
# at line 23
# at line 24
# at line 25
# at line 26
# at line 27
# at line 28
# at line 29
# at line 30
# at line 31
# at line 32
# at line 33
# at line 34
# at line 35
# at line 36
# at line 37
# at line 38
# at line 39
# at line 40
# at line 41
# at line 42
# at line 43
# at line 44
# at line 45
# at line 46
# at line 47
# at line 48
# at line 49
# at line 50
# at line 51
# at line 52
# at line 53
# at line 54
# at line 55
# at line 56
# at line 57
# at line 58
# at line 59
# at line 60
# at line 61
# at line 62
# at line 63
# at line 64
# at line 65
# at line 66
# at line 67
# at line 68
# at line 69
# at line 70
# at line 71
# at line 72
# at line 73
# at line 74
# at line 75
# at line 76
# at line 77
# at line 78
# at line 79
# at line 80
# at line 81
# at line 82
# at line 83
# at line 84
# at line 85
# at line 86
# at line 87
# at line 88
# at line 89
# at line 90
# at line 91
# at line 92
# at line 93
# at line 94
# at line 95
# at line 96
# at line 97
# at line 98
# at line 99
# at line 100
# at line 101
# at line 102
# at line 103
# at line 104
# at line 105
# at line 106
# at line 107
# at line 108
# at line 109
# at line 110
# at line 111
# at line 112
# at line 113
# at line 114
# at line 115
# at line 116
# at line 117
# at line 118
# at line 119
# at line 120
# at line 121
# at line 122
# at line 123
# at line 124
# at line 125
# at line 126
# at line 127
# at line 128
# at line 129
# at line 130
# at line 131
# at line 132
# at line 133
# at line 134
# at line 135
# at line 136
# at line 137
# at line 138
# at line 139
# at line 140
# at line 141
# at line 142
# at line 143
# at line 144
# at line 145
# at line 146
# at line 147
# at line 148
# at line 149
# at line 150
# at line 151
# at line 152
# at line 153
# at line 154
# at line 155
# at line 156
# at line 157
# at line 158
# at line 159
# at line 160
# at line 161
# at line 162
# at line 163
# at line 164
# at line 165
# at line 166
# at line 167
# at line 168
# at line 169
# at line 170
# at line 171
# at line 172
# at line 173
# at line 174
# at line 175
# at line 176
# at line 177
# at line 178
# at line 179
# at line 180
# at line 181
# at line 182
# at line 183
# at line 184
# at line 185
# at line 186
# at line 187
# at line 188
# at line 189
# at line 190
# at line 191
# at line 192
# at line 193
# at line 194
# at line 195
# at line 196
# at line 197
# at line 198
# at line 199
# at line 200
# at line 201
# at line 202
# at line 203
# at line 204
# at line 205
# at line 206
# at line 207
# at line 208
# at line 209
# at line 210
# at line 211
# at line 212
# at line 213
# at line 214
# at line 215
# at line 216
# at line 217
# at line 218
# at line 219
# at line 220
# at line 221
# at line 222
# at line 223
# at line 224
# at line 225
# at line 226
# at line 227
# at line 228
# at line 229
# at line 230
# at line 231
# at line 232
# at line 233
# at line 234
# at line 235
# at line 236
# at line 237
# at line 238
# at line 239
# at line 240
# at line 241
# at line 242
# at line 243
# at line 244
# at line 245
# at line 246
# at line 247
# at line 248
# at line 249
# at line 250
# at line 251
# at line 252
# at line 253
# at line 254
# at line 255
# at line 256
# at line 257
# at line 258
# at line 259
# at line 260
# at line 261
# at line 262
# at line 263
# at line 264
# at line 265
# at line 266
# at line 267
# at line 268
# at line 269
# at line 270
# at line 271
# at line 272
# at line 273
# at line 274
# at line 275
# at line 276
# at line 277
# at line 278
# at line 279
# at line 280
# at line 281
# at line 282
# at line 283
# at line 284
# at line 285
# at line 286
# at line 287
# at line 288
# at line 289
# at line 290
# at line 291
# at line 292
# at line 293
# at line 294
# at line 295
# at line 296
# at line 297
# at line 298
# at line 299
# at line 300
# at line 301
# at line 302
# at line 303
# at line 304
# at line 305
# at line 306
# at line 307
# at line 308
# at line 309
# at line 310
# at line 311
# at line 312
# at line 313
# at line 314
# at line 315
# at line 316
# at line 317
# at line 318
# at line 319
# at line 320
# at line 321
# at line 322
# at line 323
# at line 324
# at line 325
# at line 326
# at line 327
# at line 328
# at line 329
# at line 330
# at line 331
# at line 332
# at line 333
# at line 334
# at line 335
# at line 336
# at line 337
# at line 338
# at line 339
# at line 340
# at line 341
# at line 342
# at line 343
# at line 344
# at line 345
# at line 346
# at line 347
# at line 348
# at line 349
# at line 350
# at line 351
# at line 352
# at line 353
# at line 354
# at line 355
# at line 356
# at line 357
# at line 358
# at line 359
# at line 360
# at line 361
# at line 362
# at line 363
# at line 364
# at line 365
# at line 366
# at line 367
# at line 368
# at line 369
# at line 370
# at line 371
# at line 372
# at line 373
# at line 374
# at line 375
# at line 376
# at line 377
# at line 378
# at line 379
# at line 380
# at line 381
# at line 382
# at line 383
# at line 384
# at line 385
# at line 386
# at line 387
# at line 388
# at line 389
# at line 390
# at line 391
# at line 392
# at line 393
# at line 394
# at line 395
# at line 396
# at line 397
# at line 398
# at line 399
# at line 400
# at line 401
# at line 402
# at line 403
# at line 404
# at line 405
# at line 406
# at line 407
# at line 408
# at line 409
# at line 410
# at line 411
# at line 412
# at line 413
# at line 414
# at line 415
# at line 416
# at line 417
# at line 418
# at line 419
# at line 420
# at line 421
# at line 422
# at line 423
# at line 424
# at line 425
# at line 426
# at line 427
# at line 428
# at line 429
# at line 430
# at line 431
# at line 432
# at line 433
# at line 434
# at line 435
# at line 436
# at line 437
# at line 438
# at line 439
# at line 440
# at line 441
# at line 442
# at line 443
# at line 444
# at line 445
# at line 446
# at line 447
# at line 448
# at line 449
# at line 450
# at line 451
# at line 452
# at line 453
# at line 454
# at line 455
# at line 456
# at line 457
# at line 458
# at line 459
# at line 460
# at line 461
# at line 462
# at line 463
# at line 464
# at line 465
# at line 466
# at line 467
# at line 468
# at line 469
# at line 470
# at line 471
# at line 472
# at line 473
# at line 474
# at line 475
# at line 476
# at line 477
# at line 478
# at line 479
# at line 480
# at line 481
# at line 482
# at line 483
# at line 484
# at line 485
# at line 486
# at line 487
# at line 488
# at line 489
# at line 490
# at line 491
# at line 492
# at line 493
# at line 494
# at line 495
# at line 496
# at line 497
# at line 498
# at line 499
# at line 500
# at line 501
# at line 502
# at line 503
# at line 504
# at line 505
# at line 506
# at line 507
# at line 508
# at line 509
# at line 510
# at line 511
# at line 512
# at line 513
# at line 514
# at line 515
# at line 516
# at line 517
# at line 518
# at line 519
# at line 520
# at line 521
# at line 522
# at line 523
# at line 524
# at line 525
# at line 526
# at line 527
# at line 528
# at line 529
# at line 530
# at line 531
# at line 532
# at line 533
# at line 534
# at line 535
# at line 536
# at line 537
# at line 538
# at line 539
# at line 540
# at line 541
# at line 542
# at line 543
# at line 544
# at line 545
# at line 546
# at line 547
# at line 548
# at line 549
# at line 550
# at line 551
# at line 552
# at line 553
# at line 554
# at line 555
# at line 556
# at line 557
# at line 558
# at line 559
# at line 560
# at line 561
# at line 562
# at line 563
# at line 564
# at line 565
# at line 566
# at line 567
# at line 568
# at line 569
# at line 570
# at line 571
# at line 572
# at line 573
# at line 574
# at line 575
# at line 576
# at line 577
# at line 578
# at line 579
# at line 580
# at line 581
# at line 582
# at line 583
# at line 584
# at line 585
# at line 586
# at line 587
# at line 588
# at line 589
# at line 590
# at line 591
# at line 592
# at line 593
# at line 594
# at line 595
# at line 596
# at line 597
# at line 598
# at line 599
# at line 600
# at line 601
# at line 602
# at line 603
# at line 604
# at line 605
# at line 606
# at line 607
# at line 608
# at line 609
# at line 610
# at line 611
# at line 612
# at line 613
# at line 614
# at line 615
# at line 616
# at line 617
# at line 618
# at line 619
# at line 620
# at line 621
# at line 622
# at line 623
# at line 624
# at line 625
# at line 626
# at line 627
# at line 628
# at line 629
# at line 630
# at line 631
# at line 632
# at line 633
# at line 634
# at line 635
# at line 636
# at line 637
# at line 638
# at line 639
# at line 640
# at line 641
# at line 642
# at line 643
# at line 644
# at line 645
# at line 646
# at line 647
# at line 648
# at line 649
# at line 650
# at line 651
# at line 652
# at line 653
# at line 654
# at line 655
# at line 656
# at line 657
# at line 658
# at line 659
# at line 660
# at line 661
# at line 662
# at line 663
# at line 664
# at line 665
# at line 666
# at line 667
# at line 668
# at line 669
# at line 670
# at line 671
# at line 672
# at line 673
# at line 674
# at line 675
# at line 676
# at line 677
# at line 678
# at line 679
# at line 680
# at line 681
# at line 682
# at line 683
# at line 684
# at line 685
# at line 686
# at line 687
# at line 688
# at line 689
# at line 690
# at line 691
# at line 692
# at line 693
# at line 694
# at line 695
# at line 696
# at line 697
# at line 698
# at line 699
# at line 700
# at line 701
# at line 702
# at line 703
# at line 704
# at line 705
# at line 706
# at line 707
# at line 708
# at line 709
# at line 710
# at line 711
# at line 712
# at line 713
# at line 714
# at line 715
# at line 716
# at line 717
# at line 718
# at line 719
# at line 720
# at line 721
# at line 722
# at line 723
# at line 724
# at line 725
# at line 726
# at line 727
# at line 728
# at line 729
# at line 730
# at line 731
# at line 732
# at line 733
# at line 734
# at line 735
# at line 736
# at line 737
# at line 738
# at line 739
# at line 740
# at line 741
# at line 742
# at line 743
# at line 744
# at line 745
# at line 746
# at line 747
# at line 748
# at line 749
# at line 750
# at line 751
# at line 752
# at line 753
# at line 754
# at line 755
# at line 756
# at line 757
# at line 758
# at line 759
# at line 760
# at line 761
# at line 762
# at line 763
# at line 764
# at line 765
# at line 766
# at line 767
# at line 768
# at line 769
# at line 770
# at line 771
# at line 772
# at line 773
# at line 774
# at line 775
# at line 776
# at line 777
# at line 778
# at line 779
# at line 780
# at line 781
# at line 782
# at line 783
# at line 784
# at line 785
# at line 786
# at line 787
# at line 788
# at line 789
# at line 790
# at line 791
# at line 792
# at line 793
# at line 794
# at line 795
# at line 796
# at line 797
# at line 798
# at line 799
# at line 800
# at line 801
# at line 802
# at line 803
# at line 804
# at line 805
# at line 806
# at line 807
# at line 808
# at line 809
# at line 810
# at line 811
# at line 812
# at line 813
# at line 814
# at line 815
# at line 816
# at line 817
# at line 818
# at line 819
# at line 820
# at line 821
# at line 822
# at line 823
# at line 824
# at line 825
# at line 826
# at line 827
# at line 828
# at line 829
# at line 830
# at line 831
# at line 832
# at line 833
# at line 834
# at line 835
# at line 836
# at line 837
# at line 838
# at line 839
# at line 840
# at line 841
# at line 842
# at line 843
# at line 844
# at line 845
# at line 846
# at line 847
# at line 848
# at line 849
# at line 850
# at line 851
# at line 852
# at line 853
# at line 854
# at line 855
# at line 856
# at line 857
# at line 858
# at line 859
# at line 860
# at line 861
# at line 862
# at line 863
# at line 864
# at line 865
# at line 866
# at line 867
# at line 868
# at line 869
# at line 870
# at line 871
# at line 872
# at line 873
# at line 874
# at line 875
# at line 876
# at line 877
# at line 878
# at line 879
# at line 880
# at line 881
# at line 882
# at line 883
# at line 884
# at line 885
# at line 886
# at line 887
# at line 888
# at line 889
# at line 890
# at line 891
# at line 892
# at line 893
# at line 894
# at line 895
# at line 896
# at line 897
# at line 898
# at line 899
# at line 900
# at line 901
# at line 902
# at line 903
# at line 904
# at line 905
# at line 906
# at line 907
# at line 908
# at line 909
# at line 910
# at line 911
# at line 912
# at line 913
# at line 914
# at line 915
# at line 916
# at line 917
# at line 918
# at line 919
# at line 920
# at line 921
# at line 922
# at line 923
# at line 924
# at line 925
# at line 926
# at line 927
# at line 928
# at line 929
# at line 930
# at line 931
# at line 932
# at line 933
# at line 934
# at line 935
# at line 936
# at line 937
# at line 938
# at line 939
# at line 940
# at line 941
# at line 942
# at line 943
# at line 944
# at line 945
# at line 946
# at line 947
# at line 948
# at line 949
# at line 950
# at line 951
# at line 952
# at line 953
# at line 954
# at line 955
# at line 956
# at line 957
# at line 958
# at line 959
# at line 960
# at line 961
# at line 962
# at line 963
# at line 964
# at line 965
# at line 966
# at line 967
# at line 968
# at line 969
# at line 970
# at line 971
# at line 972
# at line 973
# at line 974
# at line 975
# at line 976
# at line 977
# at line 978
# at line 979
# at line 980
# at line 981
# at line 982
# at line 983
# at line 984
# at line 985
# at line 986
# at line 987
# at line 988
# at line 989
# at line 990
# at line 991
# at line 992
# at line 993
# at line 994
# at line 995
# at line 996
# at line 997
# at line 998
# at line 999
# at line 1000
# at line 1001
# at line 1002
# at line 1003
# at line 1004
# at line 1005
# at line 1006
# at line 1007
# at line 1008
# at line 1009
# at line 1010
# at line 1011
# at line 1012
# at line 1013
# at line 1014
# at line 1015
# at line 1016
# at line 1017
# at line 1018
# at line 1019
# at line 1020
# at line 1021
# at line 1022
# at line 1023
# at line 1024
# at line 1025
# at line 1026
# at line 1027
# at line 1028
# at line 1029
# at line 1030
# at line 1031
# at line 1032
# at line 1033
# at line 1034
# at line 1035
# at line 1036
# at line 1037
# at line 1038
# at line 1039
# at line 1040
# at line 1041
# at line 1042
# at line 1043
# at line 1044
# at line 1045
# at line 1046
# at line 1047
# at line 1048
# at line 1049
# at line 1050
# at line 1051
# at line 1052
# at line 1053
# at line 1054
# at line 1055
# at line 1056
# at line 1057
# at line 1058
# at line 1059
# at line 1060
# at line 1061
# at line 1062
# at line 1063
# at line 1064
# at line 1065
# at line 1066
# at line 1067
# at line 1068
# at line 1069
# at line 1070
# at line 1071
# at line 1072
# at line 1073
# at line 1074
# at line 1075
# at line 1076
# at line 1077
# at line 1078
# at line 1079
# at line 1080
# at line 1081
# at line 1082
# at line 1083
# at line 1084
# at line 1085
# at line 1086
# at line 1087
# at line 1088
# at line 1089
# at line 1090
# at line 1091
# at line 1092
# at line 1093
# at line 1094
# at line 1095
# at line 1096
# at line 1097
# at line 1098
# at line 1099
# at line 1100
# at line 1101
# at line 1102
# at line 1103
# at line 1104
# at line 1105
# at line 1106
# at line 1107
# at line 1108
# at line 1109
# at line 1110
# at line 1111
# at line 1112
# at line 1113
# at line 1114
# at line 1115
# at line 1116
# at line 1117
# at line 1118
# at line 1119
# at line 1120
# at line 1121
# at line 1122
# at line 1123
# at line 1124
# at line 1125
# at line 1126
# at line 1127
# at line 1128
# at line 1129
# at line 1130
# at line 1131
# at line 1132
# at line 1133
# at line 1134
# at line 1135
# at line 1136
# at line 1137
# at line 1138
# at line 1139
# at line 1140
# at line 1141
# at line 1142
# at line 1143
# at line 1144
# at line 1145
# at line 1146
# at line 1147
# at line 1148
# at line 1149
# at line 1150
# at line 1151
# at line 1152
# at line 1153
# at line 1154
# at line 1155
# at line 1156
# at line 1157
# at line 1158
# at line 1159
# at line 1160
# at line 1161
# at line 1162
# at line 1163
# at line 1164
# at line 1165
# at line 1166
# at line 1167
# at line 1168
# at line 1169
# at line 1170
# at line 1171
# at line 1172
# at line 1173
# at line 1174
# at line 1175
# at line 1176
# at line 1177
# at line 1178
# at line 1179
# at line 1180
# at line 1181
# at line 1182
# at line 1183
# at line 1184
# at line 1185
# at line 1186
# at line 1187
# at line 1188
# at line 1189
# at line 1190
# at line 1191
# at line 1192
# at line 1193
# at line 1194
# at line 1195
# at line 1196
# at line 1197
# at line 1198
# at line 1199
# at line 1200
# at line 1201
# at line 1202
# at line 1203
# at line 1204
# at line 1205
# at line 1206
# at line 1207
# at line 1208
# at line 1209
# at line 1210
# at line 1211
# at line 1212
# at line 1213
# at line 1214
# at line 1215
# at line 1216
# at line 1217
# at line 1218
# at line 1219
# at line 1220
# at line 1221
# at line 1222
# at line 1223
# at line 1224
# at line 1225
# at line 1226
# at line 1227
# at line 1228
# at line 1229
# at line 1230
# at line 1231
# at line 1232
# at line 1233
# at line 1234
# at line 1235
# at line 1236
# at line 1237
# at line 1238
# at line 1239
# at line 1240
# at line 1241
# at line 1242
# at line 1243
# at line 1244
# at line 1245
# at line 1246
# at line 1247
# at line 1248
# at line 1249
# at line 1250
# at line 1251
# at line 1252
# at line 1253
# at line 1254
# at line 1255
# at line 1256
# at line 1257
# at line 1258
# at line 1259
# at line 1260
# at line 1261
# at line 1262
# at line 1263
# at line 1264
# at line 1265
# at line 1266
# at line 1267
# at line 1268
# at line 1269
# at line 1270
# at line 1271
# at line 1272
# at line 1273
# at line 1274
# at line 1275
# at line 1276
# at line 1277
# at line 1278
# at line 1279
# at line 1280
# at line 1281
# at line 1282
# at line 1283
# at line 1284
# at line 1285
# at line 1286
# at line 1287
# at line 1288
# at line 1289
# at line 1290
# at line 1291
# at line 1292
# at line 1293
# at line 1294
# at line 1295
# at line 1296
# at line 1297
# at line 1298
# at line 1299
# at line 1300
# at line 1301
# at line 1302
# at line 1303
# at line 1304
# at line 1305
# at line 1306
# at line 1307
# at line 1308
# at line 1309
# at line 1310
# at line 1311
# at line 1312
# at line 1313
# at line 1314
# at line 1315
# at line 1316
# at line 1317
# at line 1318
# at line 1319
# at line 1320
# at line 1321
# at line 1322
# at line 1323
# at line 1324
# at line 1325
# at line 1326
# at line 1327
# at line 1328
# at line 1329
# at line 1330
# at line 1331
# at line 1332
# at line 1333
# at line 1334
# at line 1335
# at line 1336
# at line 1337
# at line 1338
# at line 1339
# at line 1340
# at line 1341
# at line 1342
# at line 1343
# at line 1344
# at line 1345
# at line 1346
# at line 1347
# at line 1348
# at line 1349
# at line 1350
# at line 1351
# at line 1352
# at line 1353
# at line 1354
# at line 1355
# at line 1356
# at line 1357
# at line 1358
# at line 1359
# at line 1360
# at line 1361
# at line 1362
# at line 1363
# at line 1364
# at line 1365
# at line 1366
# at line 1367
# at line 1368
# at line 1369
# at line 1370
# at line 1371
# at line 1372
# at line 1373
# at line 1374
# at line 1375
# at line 1376
# at line 1377
# at line 1378
# at line 1379
# at line 1380
# at line 1381
# at line 1382
# at line 1383
# at line 1384
# at line 1385
# at line 1386
# at line 1387
# at line 1388
# at line 1389
# at line 1390
# at line 1391
# at line 1392
# at line 1393
# at line 1394
# at line 1395
# at line 1396
# at line 1397
# at line 1398
# at line 1399
# at line 1400
# at line 1401
# at line 1402
# at line 1403
# at line 1404
# at line 1405
# at line 1406
# at line 1407
# at line 1408
# at line 1409
# at line 1410
# at line 1411
# at line 1412
# at line 1413
# at line 1414
# at line 1415
# at line 1416
# at line 1417
# at line 1418
# at line 1419
# at line 1420
# at line 1421
# at line 1422
# at line 1423
# at line 1424
# at line 1425
# at line 1426
# at line 1427
# at line 1428
# at line 1429
# at line 1430
# at line 1431
# at line 1432
# at line 1433
# at line 1434
# at line 1435
# at line 1436
# at line 1437
# at line 1438
# at line 1439
# at line 1440
# at line 1441
# at line 1442
# at line 1443
# at line 1444
# at line 1445
# at line 1446
# at line 1447
# at line 1448
# at line 1449
# at line 1450
# at line 1451
# at line 1452
# at line 1453
# at line 1454
# at line 1455
# at line 1456
# at line 1457
# at line 1458
# at line 1459
# at line 1460
# at line 1461
# at line 1462
# at line 1463
# at line 1464
# at line 1465
# at line 1466
# at line 1467
# at line 1468
# at line 1469
# at line 1470
# at line 1471
# at line 1472
# at line 1473
# at line 1474
# at line 1475
# at line 1476
# at line 1477
# at line 1478
# at line 1479
# at line 1480
# at line 1481
# at line 1482
# at line 1483
# at line 1484
# at line 1485
# at line 1486
# at line 1487
# at line 1488
# at line 1489
# at line 1490
# at line 1491
# at line 1492
# at line 1493
# at line 1494
# at line 1495
# at line 1496
# at line 1497
# at line 1498
# at line 1499
# at line 1500
# at line 1501
# at line 1502
# at line 1503
# at line 1504
# at line 1505
# at line 1506
# at line 1507
# at line 1508
# at line 1509
# at line 1510
# at line 1511
# at line 1512
# at line 1513
# at line 1514
# at line 1515
# at line 1516
# at line 1517
# at line 1518
# at line 1519
# at line 1520
# at line 1521
# at line 1522
# at line 1523
# at line 1524
# at line 1525
# at line 1526
# at line 1527
# at line 1528
# at line 1529
# at line 1530
# at line 1531
# at line 1532
# at line 1533
# at line 1534
# at line 1535
# at line 1536
# at line 1537
# at line 1538
# at line 1539
# at line 1540
# at line 1541
# at line 1542
# at line 1543
# at line 1544
# at line 1545
# at line 1546
# at line 1547
# at line 1548
# at line 1549
# at line 1550
# at line 1551
# at line 1552
# at line 1553
# at line 1554
# at line 1555
# at line 1556
# at line 1557
# at line 1558
# at line 1559
# at line 1560
# at line 1561
# at line 1562
# at line 1563
# at line 1564
# at line 1565
# at line 1566
# at line 1567
# at line 1568
# at line 1569
# at line 1570
# at line 1571
# at line 1572
# at line 1573
# at line 1574
# at line 1575
# at line 1576
# at line 1577
# at line 1578
# at line 1579
# at line 1580
# at line 1581
# at line 1582
# at line 1583
# at line 1584
# at line 1585
# at line 1586
# at line 1587
# at line 1588
# at line 1589
# at line 1590
# at line 1591
# at line 1592
# at line 1593
# at line 1594
# at line 1595
# at line 1596
# at line 1597
# at line 1598
# at line 1599
# at line 1600
# at line 1601
# at line 1602
# at line 1603
# at line 1604
# at line 1605
# at line 1606
# at line 1607
# at line 1608
# at line 1609
# at line 1610
# at line 1611
# at line 1612
# at line 1613
# at line 1614
# at line 1615
# at line 1616
# at line 1617
# at line 1618
# at line 1619
# at line 1620
# at line 1621
# at line 1622
# at line 1623
# at line 1624
# at line 1625
# at line 1626
# at line 1627
# at line 1628
# at line 1629
# at line 1630
# at line 1631
# at line 1632
# at line 1633
# at line 1634
# at line 1635
# at line 1636
# at line 1637
# at line 1638
# at line 1639
# at line 1640
# at line 1641
# at line 1642
# at line 1643
# at line 1644
# at line 1645
# at line 1646
# at line 1647
# at line 1648
# at line 1649
# at line 1650
# at line 1651
# at line 1652
# at line 1653
# at line 1654
# at line 1655
# at line 1656
# at line 1657
# at line 1658
# at line 1659
# at line 1660
# at line 1661
# at line 1662
# at line 1663
# at line 1664
# at line 1665
# at line 1666
# at line 1667
# at line 1668
# at line 1669
# at line 1670
# at line 1671
# at line 1672
# at line 1673
# at line 1674
# at line 1675
# at line 1676
# at line 1677
# at line 1678
# at line 1679
# at line 1680
# at line 1681
# at line 1682
# at line 1683
# at line 1684
# at line 1685
# at line 1686
# at line 1687
# at line 1688
# at line 1689
# at line 1690
# at line 1691
# at line 1692
# at line 1693
# at line 1694
# at line 1695
# at line 1696
# at line 1697
# at line 1698
# at line 1699
# at line 1700
# at line 1701
# at line 1702
# at line 1703
# at line 1704
# at line 1705
# at line 1706
# at line 1707
# at line 1708
# at line 1709
# at line 1710
# at line 1711
# at line 1712
# at line 1713
# at line 1714
# at line 1715
# at line 1716
# at line 1717
# at line 1718
# at line 1719
# at line 1720
# at line 1721
# at line 1722
# at line 1723
# at line 1724
# at line 1725
# at line 1726
# at line 1727
# at line 1728
# at line 1729
# at line 1730
# at line 1731
# at line 1732
# at line 1733
# at line 1734
# at line 1735
# at line 1736
# at line 1737
# at line 1738
# at line 1739
# at line 1740
# at line 1741
# at line 1742
# at line 1743
# at line 1744
# at line 1745
# at line 1746
# at line 1747
# at line 1748
# at line 1749
# at line 1750
# at line 1751
# at line 1752
# at line 1753
# at line 1754
# at line 1755
# at line 1756
# at line 1757
# at line 1758
# at line 1759
# at line 1760
# at line 1761
# at line 1762
# at line 1763
# at line 1764
# at line 1765
# at line 1766
# at line 1767
# at line 1768
# at line 1769
# at line 1770
# at line 1771
# at line 1772
# at line 1773
# at line 1774
# at line 1775
# at line 1776
# at line 1777
# at line 1778
# at line 1779
# at line 1780
# at line 1781
# at line 1782
# at line 1783
# at line 1784
# at line 1785
# at line 1786
# at line 1787
# at line 1788
# at line 1789
# at line 1790
# at line 1791
# at line 1792
# at line 1793
# at line 1794
# at line 1795
# at line 1796
# at line 1797
# at line 1798
# at line 1799
# at line 1800
# at line 1801
# at line 1802
# at line 1803
# at line 1804
# at line 1805
# at line 1806
# at line 1807
# at line 1808
# at line 1809
# at line 1810
# at line 1811
# at line 1812
# at line 1813
# at line 1814
# at line 1815
# at line 1816
# at line 1817
# at line 1818
# at line 1819
# at line 1820
# at line 1821
# at line 1822
# at line 1823
# at line 1824
# at line 1825
# at line 1826
# at line 1827
# at line 1828
# at line 1829
# at line 1830
# at line 1831
# at line 1832
# at line 1833
# at line 1834
# at line 1835
# at line 1836
# at line 1837
# at line 1838
# at line 1839
# at line 1840
# at line 1841
# at line 1842
# at line 1843
# at line 1844
# at line 1845
# at line 1846
# at line 1847
# at line 1848
# at line 1849
# at line 1850
# at line 1851
# at line 1852
# at line 1853
# at line 1854
# at line 1855
# at line 1856
# at line 1857
# at line 1858
# at line 1859
# at line 1860
# at line 1861
# at line 1862
# at line 1863
# at line 1864
# at line 1865
# at line 1866
# at line 1867
# at line 1868
# at line 1869
# at line 1870
# at line 1871
# at line 1872
# at line 1873
# at line 1874
# at line 1875
# at line 1876
# at line 1877
# at line 1878
# at line 1879
# at line 1880
# at line 1881
# at line 1882
# at line 1883
# at line 1884
# at line 1885
# at line 1886
# at line 1887
# at line 1888
# at line 1889
# at line 1890
# at line 1891
# at line 1892
# at line 1893
# at line 1894
# at line 1895
# at line 1896
# at line 1897
# at line 1898
# at line 1899
# at line 1900
# at line 1901
# at line 1902
# at line 1903
# at line 1904
# at line 1905
# at line 1906
# at line 1907
# at line 1908
# at line 1909
# at line 1910
# at line 1911
# at line 1912
# at line 1913
# at line 1914
# at line 1915
# at line 1916
# at line 1917
# at line 1918
# at line 1919
# at line 1920
# at line 1921
# at line 1922
# at line 1923
# at line 1924
# at line 1925
# at line 1926
# at line 1927
# at line 1928
# at line 1929
# at line 1930
# at line 1931
# at line 1932
# at line 1933
# at line 1934
# at line 1935
# at line 1936
# at line 1937
# at line 1938
# at line 1939
# at line 1940
# at line 1941
# at line 1942
# at line 1943
# at line 1944
# at line 1945
# at line 1946
# at line 1947
# at line 1948
# at line 1949
# at line 1950
# at line 1951
# at line 1952
# at line 1953
# at line 1954
# at line 1955
# at line 1956
# at line 1957
# at line 1958
# at line 1959
# at line 1960
# at line 1961
# at line 1962
# at line 1963
# at line 1964
# at line 1965
# at line 1966
# at line 1967
# at line 1968
# at line 1969
# at line 1970
# at line 1971
# at line 1972
# at line 1973
# at line 1974
# at line 1975
# at line 1976
# at line 1977
# at line 1978
# at line 1979
# at line 1980
# at line 1981
# at line 1982
# at line 1983
# at line 1984
# at line 1985
# at line 1986
# at line 1987
# at line 1988
# at line 1989
# at line 1990
# at line 1991
# at line 1992
# at line 1993
# at line 1994
# at line 1995
# at line 1996
# at line 1997
# at line 1998
# at line 1999
# at line 2000
# at line 2001
# at line 2002
# at line 2003
# at line 2004
# at line 2005
# at line 2006
# at line 2007
# at line 2008
# at line 2009
# at line 2010
# at line 2011
# at line 2012
# at line 2013
# at line 2014
# at line 2015
# at line 2016
# at line 2017
# at line 2018
# at line 2019
# at line 2020
# at line 2021
# at line 2022
# at line 2023
# at line 2024
# at line 2025
# at line 2026
# at line 2027
# at line 2028
# at line 2029
# at line 2030
# at line 2031
# at line 2032
# at line 2033
# at line 2034
# at line 2035
# at line 2036
# at line 2037
# at line 2038
# at line 2039
# at line 2040
# at line 2041
# at line 2042
# at line 2043
# at line 2044
# at line 2045
# at line 2046
# at line 2047
# at line 2048
# at line 2049
# at line 2050
# at line 2051
# at line 2052
# at line 2053
# at line 2054
# at line 2055
# at line 2056
# at line 2057
# at line 2058
# at line 2059
# at line 2060
# at line 2061
# at line 2062
# at line 2063
# at line 2064
# at line 2065
# at line 2066
# at line 2067
# at line 2068
# at line 2069
# at line 2070
# at line 2071
# at line 2072
# at line 2073
# at line 2074
# at line 2075
# at line 2076
# at line 2077
# at line 2078
# at line 2079
# at line 2080
# at line 2081
# at line 2082
# at line 2083
# at line 2084
# at line 2085
# at line 2086
# at line 2087
# at line 2088
# at line 2089
# at line 2090
# at line 2091
# at line 2092
# at line 2093
# at line 2094
# at line 2095
# at line 2096
# at line 2097
# at line 2098
# at line 2099
# at line 2100
# at line 2101
# at line 2102
# at line 2103
# at line 2104
# at line 2105
# at line 2106
# at line 2107
# at line 2108
# at line 2109
# at line 2110
# at line 2111
# at line 2112
# at line 2113
# at line 2114
# at line 2115
# at line 2116
# at line 2117
# at line 2118
# at line 2119
# at line 2120
# at line 2121
# at line 2122
# at line 2123
# at line 2124
# at line 2125
# at line 2126
# at line 2127
# at line 2128
# at line 2129
# at line 2130
# at line 2131
# at line 2132
# at line 2133
# at line 2134
# at line 2135
# at line 2136
# at line 2137
# at line 2138
# at line 2139
# at line 2140
# at line 2141
# at line 2142
# at line 2143
# at line 2144
# at line 2145
# at line 2146
# at line 2147
# at line 2148
# at line 2149
# at line 2150
# at line 2151
# at line 2152
# at line 2153
# at line 2154
# at line 2155
# at line 2156
# at line 2157
# at line 2158
# at line 2159
# at line 2160
# at line 2161
# at line 2162
# at line 2163
# at line 2164
# at line 2165
# at line 2166
# at line 2167
# at line 2168
# at line 2169
# at line 2170
# at line 2171
# at line 2172
# at line 2173
# at line 2174
# at line 2175
# at line 2176
# at line 2177
# at line 2178
# at line 2179
# at line 2180
# at line 2181
# at line 2182
# at line 2183
# at line 2184
# at line 2185
# at line 2186
# at line 2187
# at line 2188
# at line 2189
# at line 2190
# at line 2191
# at line 2192
# at line 2193
# at line 2194
# at line 2195
# at line 2196
# at line 2197
# at line 2198
# at line 2199
# at line 2200
# at line 2201
# at line 2202
# at line 2203
# at line 2204
# at line 2205
# at line 2206
# at line 2207
# at line 2208
# at line 2209
# at line 2210
# at line 2211
# at line 2212
# at line 2213
# at line 2214
# at line 2215
# at line 2216
# at line 2217
# at line 2218
# at line 2219
# at line 2220
# at line 2221
# at line 2222
# at line 2223
# at line 2224
# at line 2225
# at line 2226
# at line 2227
# at line 2228
# at line 2229
# at line 2230
# at line 2231
# at line 2232
# at line 2233
# at line 2234
# at line 2235
# at line 2236
# at line 2237
# at line 2238
# at line 2239
# at line 2240
# at line 2241
# at line 2242
# at line 2243
# at line 2244
# at line 2245
# at line 2246
# at line 2247
# at line 2248
# at line 2249
# at line 2250
# at line 2251
# at line 2252
# at line 2253
# at line 2254
# at line 2255
# at line 2256
# at line 2257
# at line 2258
# at line 2259
# at line 2260
# at line 2261
# at line 2262
# at line 2263
# at line 2264
# at line 2265
# at line 2266
# at line 2267
# at line 2268
# at line 2269
# at line 2270
# at line 2271
# at line 2272
# at line 2273
# at line 2274
# at line 2275
# at line 2276
# at line 2277
# at line 2278
# at line 2279
# at line 2280
# at line 2281
# at line 2282
# at line 2283
# at line 2284
# at line 2285
# at line 2286
# at line 2287
# at line 2288
# at line 2289
# at line 2290
# at line 2291
# at line 2292
# at line 2293
# at line 2294
# at line 2295
# at line 2296
# at line 2297
# at line 2298
# at line 2299
# at line 2300
# at line 2301
# at line 2302
# at line 2303
# at line 2304
# at line 2305
# at line 2306
# at line 2307
# at line 2308
# at line 2309
# at line 2310
# at line 2311
# at line 2312
# at line 2313
# at line 2314
# at line 2315
# at line 2316
# at line 2317
# at line 2318
# at line 2319
# at line 2320
# at line 2321
# at line 2322
# at line 2323
# at line 2324
# at line 2325
# at line 2326
# at line 2327
# at line 2328
# at line 2329
# at line 2330
# at line 2331
# at line 2332
# at line 2333
# at line 2334
# at line 2335
# at line 2336
# at line 2337
# at line 2338
# at line 2339
# at line 2340
# at line 2341
# at line 2342
# at line 2343
# at line 2344
# at line 2345
# at line 2346
# at line 2347
# at line 2348
# at line 2349
# at line 2350
# at line 2351
# at line 2352
# at line 2353
# at line 2354
# at line 2355
# at line 2356
# at line 2357
# at line 2358
# at line 2359
# at line 2360
# at line 2361
# at line 2362
# at line 2363
# at line 2364
# at line 2365
# at line 2366
# at line 2367
# at line 2368
# at line 2369
# at line 2370
# at line 2371
# at line 2372
# at line 2373
# at line 2374
# at line 2375
# at line 2376
# at line 2377
# at line 2378
# at line 2379
# at line 2380
# at line 2381
# at line 2382
# at line 2383
# at line 2384
# at line 2385
# at line 2386
# at line 2387
# at line 2388
# at line 2389
# at line 2390
# at line 2391
# at line 2392
# at line 2393
# at line 2394
# at line 2395
# at line 2396
# at line 2397
# at line 2398
# at line 2399
# at line 2400
# at line 2401
# at line 2402
# at line 2403
# at line 2404
# at line 2405
# at line 2406
# at line 2407
# at line 2408
# at line 2409
# at line 2410
# at line 2411
# at line 2412
# at line 2413
# at line 2414
# at line 2415
# at line 2416
# at line 2417
# at line 2418
# at line 2419
# at line 2420
# at line 2421
# at line 2422
# at line 2423
# at line 2424
# at line 2425
# at line 2426
# at line 2427
# at line 2428
# at line 2429
# at line 2430
# at line 2431
# at line 2432
# at line 2433
# at line 2434
# at line 2435
# at line 2436
# at line 2437
# at line 2438
# at line 2439
# at line 2440
# at line 2441
# at line 2442
# at line 2443
# at line 2444
# at line 2445
# at line 2446
# at line 2447
# at line 2448
# at line 2449
# at line 2450
# at line 2451
# at line 2452
# at line 2453
# at line 2454
# at line 2455
# at line 2456
# at line 2457
# at line 2458
# at line 2459
# at line 2460
# at line 2461
# at line 2462
# at line 2463
# at line 2464
# at line 2465
# at line 2466
# at line 2467
# at line 2468
# at line 2469
# at line 2470
# at line 2471
# at line 2472
# at line 2473
# at line 2474
# at line 2475
# at line 2476
# at line 2477
# at line 2478
# at line 2479
# at line 2480
# at line 2481
# at line 2482
# at line 2483
# at line 2484
# at line 2485
# at line 2486
# at line 2487
# at line 2488
# at line 2489
# at line 2490
# at line 2491
# at line 2492
# at line 2493
# at line 2494
# at line 2495
# at line 2496
# at line 2497
# at line 2498
# at line 2499
# at line 2500
# at line 2501
# at line 2502
# at line 2503
# at line 2504
# at line 2505
# at line 2506
# at line 2507
# at line 2508
# at line 2509
# at line 2510
# at line 2511
# at line 2512
# at line 2513
# at line 2514
# at line 2515
# at line 2516
# at line 2517
# at line 2518
# at line 2519
# at line 2520
# at line 2521
# at line 2522
# at line 2523
# at line 2524
# at line 2525
# at line 2526
# at line 2527
# at line 2528
# at line 2529
# at line 2530
# at line 2531
# at line 2532
# at line 2533
# at line 2534
# at line 2535
# at line 2536
# at line 2537
# at line 2538
# at line 2539
# at line 2540
# at line 2541
# at line 2542
# at line 2543
# at line 2544
# at line 2545
# at line 2546
# at line 2547
# at line 2548
# at line 2549
# at line 2550
# at line 2551
# at line 2552
# at line 2553
# at line 2554
# at line 2555
# at line 2556
# at line 2557
# at line 2558
# at line 2559
# at line 2560
# at line 2561
# at line 2562
# at line 2563
# at line 2564
# at line 2565
# at line 2566
# at line 2567
# at line 2568
# at line 2569
# at line 2570
# at line 2571
# at line 2572
# at line 2573
# at line 2574
# at line 2575
# at line 2576
# at line 2577
# at line 2578
# at line 2579
# at line 2580
# at line 2581
# at line 2582
# at line 2583
# at line 2584
# at line 2585
# at line 2586
# at line 2587
# at line 2588
# at line 2589
# at line 2590
# at line 2591
# at line 2592
# at line 2593
# at line 2594
# at line 2595
# at line 2596
# at line 2597
# at line 2598
# at line 2599
# at line 2600
# at line 2601
# at line 2602
# at line 2603
# at line 2604
# at line 2605
# at line 2606
# at line 2607
# at line 2608
# at line 2609
# at line 2610
# at line 2611
# at line 2612
# at line 2613
# at line 2614
# at line 2615
# at line 2616
# at line 2617
# at line 2618
# at line 2619
# at line 2620
# at line 2621
# at line 2622
# at line 2623
# at line 2624
# at line 2625
# at line 2626
# at line 2627
# at line 2628
# at line 2629
# at line 2630
# at line 2631
# at line 2632
# at line 2633
# at line 2634
# at line 2635
# at line 2636
# at line 2637
# at line 2638
# at line 2639
# at line 2640
# at line 2641
# at line 2642
# at line 2643
# at line 2644
# at line 2645
# at line 2646
# at line 2647
# at line 2648
# at line 2649
# at line 2650
# at line 2651
# at line 2652
# at line 2653
# at line 2654
# at line 2655
# at line 2656
# at line 2657
# at line 2658
# at line 2659
# at line 2660
# at line 2661
# at line 2662
# at line 2663
# at line 2664
# at line 2665
# at line 2666
# at line 2667
# at line 2668
# at line 2669
# at line 2670
# at line 2671
# at line 2672
# at line 2673
# at line 2674
# at line 2675
# at line 2676
# at line 2677
# at line 2678
# at line 2679
# at line 2680
# at line 2681
# at line 2682
# at line 2683
# at line 2684
# at line 2685
# at line 2686
# at line 2687
# at line 2688
# at line 2689
# at line 2690
# at line 2691
# at line 2692
# at line 2693
# at line 2694
# at line 2695
# at line 2696
# at line 2697
# at line 2698
# at line 2699
# at line 2700
# at line 2701
# at line 2702
# at line 2703
# at line 2704
# at line 2705
# at line 2706
# at line 2707
# at line 2708
# at line 2709
# at line 2710
# at line 2711
# at line 2712
# at line 2713
# at line 2714
# at line 2715
# at line 2716
# at line 2717
# at line 2718
# at line 2719
# at line 2720
# at line 2721
# at line 2722
# at line 2723
# at line 2724
# at line 2725
# at line 2726
# at line 2727
# at line 2728
# at line 2729
# at line 2730
# at line 2731
# at line 2732
# at line 2733
# at line 2734
# at line 2735
# at line 2736
# at line 2737
# at line 2738
# at line 2739
# at line 2740
# at line 2741
# at line 2742
# at line 2743
# at line 2744
# at line 2745
# at line 2746
# at line 2747
# at line 2748
# at line 2749
# at line 2750
# at line 2751
# at line 2752
# at line 2753
# at line 2754
# at line 2755
# at line 2756
# at line 2757
# at line 2758
# at line 2759
# at line 2760
# at line 2761
# at line 2762
# at line 2763
# at line 2764
# at line 2765
# at line 2766
# at line 2767
# at line 2768
# at line 2769
# at line 2770
# at line 2771
# at line 2772
# at line 2773
# at line 2774
# at line 2775
# at line 2776
# at line 2777
# at line 2778
# at line 2779
# at line 2780
# at line 2781
# at line 2782
# at line 2783
# at line 2784
# at line 2785
# at line 2786
# at line 2787
# at line 2788
# at line 2789
# at line 2790
# at line 2791
# at line 2792
# at line 2793
# at line 2794
# at line 2795
# at line 2796
# at line 2797
# at line 2798
# at line 2799
# at line 2800
# at line 2801
# at line 2802
# at line 2803
# at line 2804
# at line 2805
# at line 2806
# at line 2807
# at line 2808
# at line 2809
# at line 2810
# at line 2811
# at line 2812
# at line 2813
# at line 2814
# at line 2815
# at line 2816
# at line 2817
# at line 2818
# at line 2819
# at line 2820
# at line 2821
# at line 2822
# at line 2823
# at line 2824
# at line 2825
# at line 2826
# at line 2827
# at line 2828
# at line 2829
# at line 2830
# at line 2831
# at line 2832
# at line 2833
# at line 2834
# at line 2835
# at line 2836
# at line 2837
# at line 2838
# at line 2839
# at line 2840
# at line 2841
# at line 2842
# at line 2843
# at line 2844
# at line 2845
# at line 2846
# at line 2847
# at line 2848
# at line 2849
# at line 2850
# at line 2851
# at line 2852
# at line 2853
# at line 2854
# at line 2855
# at line 2856
# at line 2857
# at line 2858
# at line 2859
# at line 2860
# at line 2861
# at line 2862
# at line 2863
# at line 2864
# at line 2865
# at line 2866
# at line 2867
# at line 2868
# at line 2869
# at line 2870
# at line 2871
# at line 2872
# at line 2873
# at line 2874
# at line 2875
# at line 2876
# at line 2877
# at line 2878
# at line 2879
# at line 2880
# at line 2881
# at line 2882
# at line 2883
# at line 2884
# at line 2885
# at line 2886
# at line 2887
# at line 2888
# at line 2889
# at line 2890
# at line 2891
# at line 2892
# at line 2893
# at line 2894
# at line 2895
# at line 2896
# at line 2897
# at line 2898
# at line 2899
# at line 2900
# at line 2901
# at line 2902
# at line 2903
# at line 2904
# at line 2905
# at line 2906
# at line 2907
# at line 2908
# at line 2909
# at line 2910
# at line 2911
# at line 2912
# at line 2913
# at line 2914
# at line 2915
# at line 2916
# at line 2917
# at line 2918
# at line 2919
# at line 2920
# at line 2921
# at line 2922
# at line 2923
# at line 2924
# at line 2925
# at line 2926
# at line 2927
# at line 2928
# at line 2929
# at line 2930
# at line 2931
# at line 2932
# at line 2933
# at line 2934
# at line 2935
# at line 2936
# at line 2937
# at line 2938
# at line 2939
# at line 2940
# at line 2941
# at line 2942
# at line 2943
# at line 2944
# at line 2945
# at line 2946
# at line 2947
# at line 2948
# at line 2949
# at line 2950
# at line 2951
# at line 2952
# at line 2953
# at line 2954
# at line 2955
# at line 2956
# at line 2957
# at line 2958
# at line 2959
# at line 2960
# at line 2961
# at line 2962
# at line 2963
# at line 2964
# at line 2965
# at line 2966
# at line 2967
# at line 2968
# at line 2969
# at line 2970
# at line 2971
# at line 2972
# at line 2973
# at line 2974
# at line 2975
# at line 2976
# at line 2977
# at line 2978
# at line 2979
# at line 2980
# at line 2981
# at line 2982
# at line 2983
# at line 2984
# at line 2985
# at line 2986
# at line 2987
# at line 2988
# at line 2989
# at line 2990
# at line 2991
# at line 2992
# at line 2993
# at line 2994
# at line 2995
# at line 2996
# at line 2997
# at line 2998
# at line 2999
# at line 3000
# at line 3001
# at line 3002
# at line 3003
# at line 3004
# at line 3005
# at line 3006
# at line 3007
# at line 3008
# at line 3009
# at line 3010
# at line 3011
# at line 3012
# at line 3013
# at line 3014
# at line 3015
# at line 3016
# at line 3017
# at line 3018
# at line 3019
# at line 3020
# at line 3021
# at line 3022
# at line 3023
# at line 3024
# at line 3025
# at line 3026
# at line 3027
# at line 3028
# at line 3029
# at line 3030
# at line 3031
# at line 3032
# at line 3033
# at line 3034
# at line 3035
# at line 3036
# at line 3037
# at line 3038
# at line 3039
# at line 3040
# at line 3041
# at line 3042
# at line 3043
# at line 3044
# at line 3045
# at line 3046
# at line 3047
# at line 3048
# at line 3049
# at line 3050
# at line 3051
# at line 3052
# at line 3053
# at line 3054
# at line 3055
# at line 3056
# at line 3057
# at line 3058
# at line 3059
# at line 3060
# at line 3061
# at line 3062
# at line 3063
# at line 3064
# at line 3065
# at line 3066
# at line 3067
# at line 3068
# at line 3069
# at line 3070
# at line 3071
# at line 3072
# at line 3073
# at line 3074
# at line 3075
# at line 3076
# at line 3077
# at line 3078
# at line 3079
# at line 3080
# at line 3081
# at line 3082
# at line 3083
# at line 3084
# at line 3085
# at line 3086
# at line 3087
# at line 3088
# at line 3089
# at line 3090
# at line 3091
# at line 3092
# at line 3093
# at line 3094
# at line 3095
# at line 3096
# at line 3097
# at line 3098
# at line 3099
# at line 3100
# at line 3101
# at line 3102
# at line 3103
# at line 3104
# at line 3105
# at line 3106
# at line 3107
# at line 3108
# at line 3109
# at line 3110
# at line 3111
# at line 3112
# at line 3113
# at line 3114
# at line 3115
# at line 3116
# at line 3117
# at line 3118
# at line 3119
# at line 3120
# at line 3121
# at line 3122
# at line 3123
# at line 3124
# at line 3125
# at line 3126
# at line 3127
# at line 3128
# at line 3129
# at line 3130
# at line 3131
# at line 3132
# at line 3133
# at line 3134
# at line 3135
# at line 3136
# at line 3137
# at line 3138
# at line 3139
# at line 3140
# at line 3141
# at line 3142
# at line 3143
# at line 3144
# at line 3145
# at line 3146
# at line 3147
# at line 3148
# at line 3149
# at line 3150
# at line 3151
# at line 3152
# at line 3153
# at line 3154
# at line 3155
# at line 3156
# at line 3157
# at line 3158
# at line 3159
# at line 3160
# at line 3161
# at line 3162
# at line 3163
# at line 3164
# at line 3165
# at line 3166
# at line 3167
# at line 3168
# at line 3169
# at line 3170
# at line 3171
# at line 3172
# at line 3173
# at line 3174
# at line 3175
# at line 3176
# at line 3177
# at line 3178
# at line 3179
# at line 3180
# at line 3181
# at line 3182
# at line 3183
# at line 3184
# at line 3185
# at line 3186
# at line 3187
# at line 3188
# at line 3189
# at line 3190
# at line 3191
# at line 3192
# at line 3193
# at line 3194
# at line 3195
# at line 3196
# at line 3197
# at line 3198
# at line 3199
# at line 3200
# at line 3201
# at line 3202
# at line 3203
# at line 3204
# at line 3205
# at line 3206
# at line 3207
# at line 3208
# at line 3209
# at line 3210
# at line 3211
# at line 3212
# at line 3213
# at line 3214
# at line 3215
# at line 3216
# at line 3217
# at line 3218
# at line 3219
# at line 3220
# at line 3221
# at line 3222
# at line 3223
# at line 3224
# at line 3225
# at line 3226
# at line 3227
# at line 3228
# at line 3229
# at line 3230
# at line 3231
# at line 3232
# at line 3233
# at line 3234
# at line 3235
# at line 3236
# at line 3237
# at line 3238
# at line 3239
# at line 3240
# at line 3241
# at line 3242
# at line 3243
# at line 3244
# at line 3245
# at line 3246
# at line 3247
# at line 3248
# at line 3249
# at line 3250
# at line 3251
# at line 3252
# at line 3253
# at line 3254
# at line 3255
# at line 3256
# at line 3257
# at line 3258
# at line 3259
# at line 3260
# at line 3261
# at line 3262
# at line 3263
# at line 3264
# at line 3265
# at line 3266
# at line 3267
# at line 3268
# at line 3269
# at line 3270
# at line 3271
# at line 3272
# at line 3273
# at line 3274
# at line 3275
# at line 3276
# at line 3277
# at line 3278
# at line 3279
# at line 3280
# at line 3281
# at line 3282
# at line 3283
# at line 3284
# at line 3285
# at line 3286
# at line 3287
# at line 3288
# at line 3289
# at line 3290
# at line 3291
# at line 3292
# at line 3293
# at line 3294
# at line 3295
# at line 3296
# at line 3297
# at line 3298
# at line 3299
# at line 3300
# at line 3301
# at line 3302
# at line 3303
# at line 3304
# at line 3305
# at line 3306
# at line 3307
# at line 3308
# at line 3309
# at line 3310
# at line 3311
# at line 3312
# at line 3313
# at line 3314
# at line 3315
# at line 3316
# at line 3317
# at line 3318
# at line 3319
# at line 3320
# at line 3321
# at line 3322
# at line 3323
# at line 3324
# at line 3325
# at line 3326
# at line 3327
# at line 3328
# at line 3329
# at line 3330
# at line 3331
# at line 3332
# at line 3333
# at line 3334
# at line 3335
# at line 3336
# at line 3337
# at line 3338
# at line 3339
# at line 3340
# at line 3341
# at line 3342
# at line 3343
# at line 3344
# at line 3345
# at line 3346
# at line 3347
# at line 3348
# at line 3349
# at line 3350
# at line 3351
# at line 3352
# at line 3353
# at line 3354
# at line 3355
# at line 3356
# at line 3357
# at line 3358
# at line 3359
# at line 3360
# at line 3361
# at line 3362
# at line 3363
# at line 3364
# at line 3365
# at line 3366
# at line 3367
# at line 3368
# at line 3369
# at line 3370
# at line 3371
# at line 3372
# at line 3373
# at line 3374
# at line 3375
# at line 3376
# at line 3377
# at line 3378
# at line 3379
# at line 3380
# at line 3381
# at line 3382
# at line 3383
# at line 3384
# at line 3385
# at line 3386
# at line 3387
# at line 3388
# at line 3389
# at line 3390
# at line 3391
# at line 3392
# at line 3393
# at line 3394
# at line 3395
# at line 3396
# at line 3397
# at line 3398
# at line 3399
# at line 3400
# at line 3401
# at line 3402
# at line 3403
# at line 3404
# at line 3405
# at line 3406
# at line 3407
# at line 3408
# at line 3409
# at line 3410
# at line 3411
# at line 3412
# at line 3413
# at line 3414
# at line 3415
# at line 3416
# at line 3417
# at line 3418
# at line 3419
# at line 3420
# at line 3421
# at line 3422
# at line 3423
# at line 3424
# at line 3425
# at line 3426
# at line 3427
# at line 3428
# at line 3429
# at line 3430
# at line 3431
# at line 3432
# at line 3433
# at line 3434
# at line 3435
# at line 3436
# at line 3437
# at line 3438
# at line 3439
# at line 3440
# at line 3441
# at line 3442
# at line 3443
# at line 3444
# at line 3445
# at line 3446
# at line 3447
# at line 3448
# at line 3449
# at line 3450
# at line 3451
# at line 3452
# at line 3453
# at line 3454
# at line 3455
# at line 3456
# at line 3457
# at line 3458
# at line 3459
# at line 3460
# at line 3461
# at line 3462
# at line 3463
# at line 3464
# at line 3465
# at line 3466
# at line 3467
# at line 3468
# at line 3469
# at line 3470
# at line 3471
# at line 3472
# at line 3473
# at line 3474
# at line 3475
# at line 3476
# at line 3477
# at line 3478
# at line 3479
# at line 3480
# at line 3481
# at line 3482
# at line 3483
# at line 3484
# at line 3485
# at line 3486
# at line 3487
# at line 3488
# at line 3489
# at line 3490
# at line 3491
# at line 3492
# at line 3493
# at line 3494
# at line 3495
# at line 3496
# at line 3497
# at line 3498
# at line 3499
# at line 3500
# at line 3501
# at line 3502
# at line 3503
# at line 3504
# at line 3505
# at line 3506
# at line 3507
# at line 3508
# at line 3509
# at line 3510
# at line 3511
# at line 3512
# at line 3513
# at line 3514
# at line 3515
# at line 3516
# at line 3517
# at line 3518
# at line 3519
# at line 3520
# at line 3521
# at line 3522
# at line 3523
# at line 3524
# at line 3525
# at line 3526
# at line 3527
# at line 3528
# at line 3529
# at line 3530
# at line 3531
# at line 3532
# at line 3533
# at line 3534
# at line 3535
# at line 3536
# at line 3537
# at line 3538
# at line 3539
# at line 3540
# at line 3541
# at line 3542
# at line 3543
# at line 3544
# at line 3545
# at line 3546
# at line 3547
# at line 3548
# at line 3549
# at line 3550
# at line 3551
# at line 3552
# at line 3553
# at line 3554
# at line 3555
# at line 3556
# at line 3557
# at line 3558
# at line 3559
# at line 3560
# at line 3561
# at line 3562
# at line 3563
# at line 3564
# at line 3565
# at line 3566
# at line 3567
# at line 3568
# at line 3569
# at line 3570
# at line 3571
# at line 3572
# at line 3573
# at line 3574
# at line 3575
# at line 3576
# at line 3577
# at line 3578
# at line 3579
# at line 3580
# at line 3581
# at line 3582
# at line 3583
# at line 3584
# at line 3585
# at line 3586
# at line 3587
# at line 3588
# at line 3589
# at line 3590
# at line 3591
# at line 3592
# at line 3593
# at line 3594
# at line 3595
# at line 3596
# at line 3597
# at line 3598
# at line 3599
# at line 3600
# at line 3601
# at line 3602
# at line 3603
# at line 3604
# at line 3605
# at line 3606
# at line 3607
# at line 3608
# at line 3609
# at line 3610
# at line 3611
# at line 3612
# at line 3613
# at line 3614
# at line 3615
# at line 3616
# at line 3617
# at line 3618
# at line 3619
# at line 3620
# at line 3621
# at line 3622
# at line 3623
# at line 3624
# at line 3625
# at line 3626
# at line 3627
# at line 3628
# at line 3629
# at line 3630
# at line 3631
# at line 3632
# at line 3633
# at line 3634
# at line 3635
# at line 3636
# at line 3637
# at line 3638
# at line 3639
# at line 3640
# at line 3641
# at line 3642
# at line 3643
# at line 3644
# at line 3645
# at line 3646
# at line 3647
# at line 3648
# at line 3649
# at line 3650
# at line 3651
# at line 3652
# at line 3653
# at line 3654
# at line 3655
# at line 3656
# at line 3657
# at line 3658
# at line 3659
# at line 3660
# at line 3661
# at line 3662
# at line 3663
# at line 3664
# at line 3665
# at line 3666
# at line 3667
# at line 3668
# at line 3669
# at line 3670
# at line 3671
# at line 3672
# at line 3673
# at line 3674
# at line 3675
# at line 3676
# at line 3677
# at line 3678
# at line 3679
# at line 3680
# at line 3681
# at line 3682
# at line 3683
# at line 3684
# at line 3685
# at line 3686
# at line 3687
# at line 3688
# at line 3689
# at line 3690
# at line 3691
# at line 3692
# at line 3693
# at line 3694
# at line 3695
# at line 3696
# at line 3697
# at line 3698
# at line 3699
# at line 3700
# at line 3701
# at line 3702
# at line 3703
# at line 3704
# at line 3705
# at line 3706
# at line 3707
# at line 3708
# at line 3709
# at line 3710
# at line 3711
# at line 3712
# at line 3713
# at line 3714
# at line 3715
# at line 3716
# at line 3717
# at line 3718
# at line 3719
# at line 3720
# at line 3721
# at line 3722
# at line 3723
# at line 3724
# at line 3725
# at line 3726
# at line 3727
# at line 3728
# at line 3729
# at line 3730
# at line 3731
# at line 3732
# at line 3733
# at line 3734
# at line 3735
# at line 3736
# at line 3737
# at line 3738
# at line 3739
# at line 3740
# at line 3741
# at line 3742
# at line 3743
# at line 3744
# at line 3745
# at line 3746
# at line 3747
# at line 3748
# at line 3749
# at line 3750
# at line 3751
# at line 3752
# at line 3753
# at line 3754
# at line 3755
# at line 3756
# at line 3757
# at line 3758
# at line 3759
# at line 3760
# at line 3761
# at line 3762
# at line 3763
# at line 3764
# at line 3765
# at line 3766
# at line 3767
# at line 3768
# at line 3769
# at line 3770
# at line 3771
# at line 3772
# at line 3773
# at line 3774
# ...
# at line 98899
# at line 98900
# at line 98901
# at line 98902
# at line 98903
# at line 98904
# at line 98905
# at line 98906
# at line 98907
# at line 98908
# at line 98909
# at line 98910
# at line 98911
# at line 98912
# at line 98913
# at line 98914
# at line 98915
# at line 98916
# at line 98917
# at line 98918
# at line 98919
# at line 98920
# at line 98921
# at line 98922
# at line 98923
# at line 98924
# at line 98925
# at line 98926
# at line 98927
# at line 98928
# at line 98929
# at line 98930
# at line 98931
# at line 98932
# at line 98933
# at line 98934
# at line 98935
# at line 98936
# at line 98937
# at line 98938
# at line 98939
# at line 98940
# at line 98941
# at line 98942
# at line 98943
# at line 98944
# at line 98945
# at line 98946
# at line 98947
# at line 98948
# at line 98949
# at line 98950
# at line 98951
# at line 98952
# at line 98953
# at line 98954
# at line 98955
# at line 98956
# at line 98957
# at line 98958
# at line 98959
# at line 98960
# at line 98961
# at line 98962
# at line 98963
# at line 98964
# at line 98965
# at line 98966
# at line 98967
# at line 98968
# at line 98969
# at line 98970
# at line 98971
# at line 98972
# at line 98973
# at line 98974
# at line 98975
# at line 98976
# at line 98977
# at line 98978
# at line 98979
# at line 98980
# at line 98981
# at line 98982
# at line 98983
# at line 98984
# at line 98985
# at line 98986
# at line 98987
# at line 98988
# at line 98989
# at line 98990
# at line 98991
# at line 98992
# at line 98993
# at line 98994
# at line 98995
# at line 98996
# at line 98997
# at line 98998
# at line 98999
# at line 99000
# at line 99001
# at line 99002
# at line 99003
# at line 99004
# at line 99005
# at line 99006
# at line 99007
# at line 99008
# at line 99009
# at line 99010
# at line 99011
# at line 99012
# at line 99013
# at line 99014
# at line 99015
# at line 99016
# at line 99017
# at line 99018
# at line 99019
# at line 99020
# at line 99021
# at line 99022
# at line 99023
# at line 99024
# at line 99025
# at line 99026
# at line 99027
# at line 99028
# at line 99029
# at line 99030
# at line 99031
# at line 99032
# at line 99033
# at line 99034
# at line 99035
# at line 99036
# at line 99037
# at line 99038
# at line 99039
# at line 99040
# at line 99041
# at line 99042
# at line 99043
# at line 99044
# at line 99045
# at line 99046
# at line 99047
# at line 99048
# at line 99049
# at line 99050
# at line 99051
# at line 99052
# at line 99053
# at line 99054
# at line 99055
# at line 99056
# at line 99057
# at line 99058
# at line 99059
# at line 99060
# at line 99061
# at line 99062
# at line 99063
# at line 99064
# at line 99065
# at line 99066
# at line 99067
# at line 99068
# at line 99069
# at line 99070
# at line 99071
# at line 99072
# at line 99073
# at line 99074
# at line 99075
# at line 99076
# at line 99077
# at line 99078
# at line 99079
# at line 99080
# at line 99081
# at line 99082
# at line 99083
# at line 99084
# at line 99085
# at line 99086
# at line 99087
# at line 99088
# at line 99089
# at line 99090
# at line 99091
# at line 99092
# at line 99093
# at line 99094
# at line 99095
# at line 99096
# at line 99097
# at line 99098
# at line 99099
# at line 99100
# at line 99101
# at line 99102
# at line 99103
# at line 99104
# at line 99105
# at line 99106
# at line 99107
# at line 99108
# at line 99109
# at line 99110
# at line 99111
# at line 99112
# at line 99113
# at line 99114
# at line 99115
# at line 99116
# at line 99117
# at line 99118
# at line 99119
# at line 99120
# at line 99121
# at line 99122
# at line 99123
# at line 99124
# at line 99125
# at line 99126
# at line 99127
# at line 99128
# at line 99129
# at line 99130
# at line 99131
# at line 99132
# at line 99133
# at line 99134
# at line 99135
# at line 99136
# at line 99137
# at line 99138
# at line 99139
# at line 99140
# at line 99141
# at line 99142
# at line 99143
# at line 99144
# at line 99145
# at line 99146
# at line 99147
# at line 99148
# at line 99149
# at line 99150
# at line 99151
# at line 99152
# at line 99153
# at line 99154
# at line 99155
# at line 99156
# at line 99157
# at line 99158
# at line 99159
# at line 99160
# at line 99161
# at line 99162
# at line 99163
# at line 99164
# at line 99165
# at line 99166
# at line 99167
# at line 99168
# at line 99169
# at line 99170
# at line 99171
# at line 99172
# at line 99173
# at line 99174
# at line 99175
# at line 99176
# at line 99177
# at line 99178
# at line 99179
# at line 99180
# at line 99181
# at line 99182
# at line 99183
# at line 99184
# at line 99185
# at line 99186
# at line 99187
# at line 99188
# at line 99189
# at line 99190
# at line 99191
# at line 99192
# at line 99193
# at line 99194
# at line 99195
# at line 99196
# at line 99197
# at line 99198
# at line 99199
# at line 99200
# at line 99201
# at line 99202
# at line 99203
# at line 99204
# at line 99205
# at line 99206
# at line 99207
# at line 99208
# at line 99209
# at line 99210
# at line 99211
# at line 99212
# at line 99213
# at line 99214
# at line 99215
# at line 99216
# at line 99217
# at line 99218
# at line 99219
# at line 99220
# at line 99221
# at line 99222
# at line 99223
# at line 99224
# at line 99225
# at line 99226
# at line 99227
# at line 99228
# at line 99229
# at line 99230
# at line 99231
# at line 99232
# at line 99233
# at line 99234
# at line 99235
# at line 99236
# at line 99237
# at line 99238
# at line 99239
# at line 99240
# at line 99241
# at line 99242
# at line 99243
# at line 99244
# at line 99245
# at line 99246
# at line 99247
# at line 99248
# at line 99249
# at line 99250
# at line 99251
# at line 99252
# at line 99253
# at line 99254
# at line 99255
# at line 99256
# at line 99257
# at line 99258
# at line 99259
# at line 99260
# at line 99261
# at line 99262
# at line 99263
# at line 99264
# at line 99265
# at line 99266
# at line 99267
# at line 99268
# at line 99269
# at line 99270
# at line 99271
# at line 99272
# at line 99273
# at line 99274
# at line 99275
# at line 99276
# at line 99277
# at line 99278
# at line 99279
# at line 99280
# at line 99281
# at line 99282
# at line 99283
# at line 99284
# at line 99285
# at line 99286
# at line 99287
# at line 99288
# at line 99289
# at line 99290
# at line 99291
# at line 99292
# at line 99293
# at line 99294
# at line 99295
# at line 99296
# at line 99297
# at line 99298
# at line 99299
# at line 99300
# at line 99301
# at line 99302
# at line 99303
# at line 99304
# at line 99305
# at line 99306
# at line 99307
# at line 99308
# at line 99309
# at line 99310
# at line 99311
# at line 99312
# at line 99313
# at line 99314
# at line 99315
# at line 99316
# at line 99317
# at line 99318
# at line 99319
# at line 99320
# at line 99321
# at line 99322
# at line 99323
# at line 99324
# at line 99325
# at line 99326
# at line 99327
# at line 99328
# at line 99329
# at line 99330
# at line 99331
# at line 99332
# at line 99333
# at line 99334
# at line 99335
# at line 99336
# at line 99337
# at line 99338
# at line 99339
# at line 99340
# at line 99341
# at line 99342
# at line 99343
# at line 99344
# at line 99345
# at line 99346
# at line 99347
# at line 99348
# at line 99349
# at line 99350
# at line 99351
# at line 99352
# at line 99353
# at line 99354
# at line 99355
# at line 99356
# at line 99357
# at line 99358
# at line 99359
# at line 99360
# at line 99361
# at line 99362
# at line 99363
# at line 99364
# at line 99365
# at line 99366
# at line 99367
# at line 99368
# at line 99369
# at line 99370
# at line 99371
# at line 99372
# at line 99373
# at line 99374
# at line 99375
# at line 99376
# at line 99377
# at line 99378
# at line 99379
# at line 99380
# at line 99381
# at line 99382
# at line 99383
# at line 99384
# at line 99385
# at line 99386
# at line 99387
# at line 99388
# at line 99389
# at line 99390
# at line 99391
# at line 99392
# at line 99393
# at line 99394
# at line 99395
# at line 99396
# at line 99397
# at line 99398
# at line 99399
# at line 99400
# at line 99401
# at line 99402
# at line 99403
# at line 99404
# at line 99405
# at line 99406
# at line 99407
# at line 99408
# at line 99409
# at line 99410
# at line 99411
# at line 99412
# at line 99413
# at line 99414
# at line 99415
# at line 99416
# at line 99417
# at line 99418
# at line 99419
# at line 99420
# at line 99421
# at line 99422
# at line 99423
# at line 99424
# at line 99425
# at line 99426
# at line 99427
# at line 99428
# at line 99429
# at line 99430
# at line 99431
# at line 99432
# at line 99433
# at line 99434
# at line 99435
# at line 99436
# at line 99437
# at line 99438
# at line 99439
# at line 99440
# at line 99441
# at line 99442
# at line 99443
# at line 99444
# at line 99445
# at line 99446
# at line 99447
# at line 99448
# at line 99449
# at line 99450
# at line 99451
# at line 99452
# at line 99453
# at line 99454
# at line 99455
# at line 99456
# at line 99457
# at line 99458
# at line 99459
# at line 99460
# at line 99461
# at line 99462
# at line 99463
# at line 99464
# at line 99465
# at line 99466
# at line 99467
# at line 99468
# at line 99469
# at line 99470
# at line 99471
# at line 99472
# at line 99473
# at line 99474
# at line 99475
# at line 99476
# at line 99477
# at line 99478
# at line 99479
# at line 99480
# at line 99481
# at line 99482
# at line 99483
# at line 99484
# at line 99485
# at line 99486
# at line 99487
# at line 99488
# at line 99489
# at line 99490
# at line 99491
# at line 99492
# at line 99493
# at line 99494
# at line 99495
# at line 99496
# at line 99497
# at line 99498
# at line 99499
# at line 99500
# at line 99501
# at line 99502
# at line 99503
# at line 99504
# at line 99505
# at line 99506
# at line 99507
# at line 99508
# at line 99509
# at line 99510
# at line 99511
# at line 99512
# at line 99513
# at line 99514
# at line 99515
# at line 99516
# at line 99517
# at line 99518
# at line 99519
# at line 99520
# at line 99521
# at line 99522
# at line 99523
# at line 99524
# at line 99525
# at line 99526
# at line 99527
# at line 99528
# at line 99529
# at line 99530
# at line 99531
# at line 99532
# at line 99533
# at line 99534
# at line 99535
# at line 99536
# at line 99537
# at line 99538
# at line 99539
# at line 99540
# at line 99541
# at line 99542
# at line 99543
# at line 99544
# at line 99545
# at line 99546
# at line 99547
# at line 99548
# at line 99549
# at line 99550
# at line 99551
# at line 99552
# at line 99553
# at line 99554
# at line 99555
# at line 99556
# at line 99557
# at line 99558
# at line 99559
# at line 99560
# at line 99561
# at line 99562
# at line 99563
# at line 99564
# at line 99565
# at line 99566
# at line 99567
# at line 99568
# at line 99569
# at line 99570
# at line 99571
# at line 99572
# at line 99573
# at line 99574
# at line 99575
# at line 99576
# at line 99577
# at line 99578
# at line 99579
# at line 99580
# at line 99581
# at line 99582
# at line 99583
# at line 99584
# at line 99585
# at line 99586
# at line 99587
# at line 99588
# at line 99589
# at line 99590
# at line 99591
# at line 99592
# at line 99593
# at line 99594
# at line 99595
# at line 99596
# at line 99597
# at line 99598
# at line 99599
# at line 99600
# at line 99601
# at line 99602
# at line 99603
# at line 99604
# at line 99605
# at line 99606
# at line 99607
# at line 99608
# at line 99609
# at line 99610
# at line 99611
# at line 99612
# at line 99613
# at line 99614
# at line 99615
# at line 99616
# at line 99617
# at line 99618
# at line 99619
# at line 99620
# at line 99621
# at line 99622
# at line 99623
# at line 99624
# at line 99625
# at line 99626
# at line 99627
# at line 99628
# at line 99629
# at line 99630
# at line 99631
# at line 99632
# at line 99633
# at line 99634
# at line 99635
# at line 99636
# at line 99637
# at line 99638
# at line 99639
# at line 99640
# at line 99641
# at line 99642
# at line 99643
# at line 99644
# at line 99645
# at line 99646
# at line 99647
# at line 99648
# at line 99649
# at line 99650
# at line 99651
# at line 99652
# at line 99653
# at line 99654
# at line 99655
# at line 99656
# at line 99657
# at line 99658
# at line 99659
# at line 99660
# at line 99661
# at line 99662
# at line 99663
# at line 99664
# at line 99665
# at line 99666
# at line 99667
# at line 99668
# at line 99669
# at line 99670
# at line 99671
# at line 99672
# at line 99673
# at line 99674
# at line 99675
# at line 99676
# at line 99677
# at line 99678
# at line 99679
# at line 99680
# at line 99681
# at line 99682
# at line 99683
# at line 99684
# at line 99685
# at line 99686
# at line 99687
# at line 99688
# at line 99689
# at line 99690
# at line 99691
# at line 99692
# at line 99693
# at line 99694
# at line 99695
# at line 99696
# at line 99697
# at line 99698
# at line 99699
# at line 99700
# at line 99701
# at line 99702
# at line 99703
# at line 99704
# at line 99705
# at line 99706
# at line 99707
# at line 99708
# at line 99709
# at line 99710
# at line 99711
# at line 99712
# at line 99713
# at line 99714
# at line 99715
# at line 99716
# at line 99717
# at line 99718
# at line 99719
# at line 99720
# at line 99721
# at line 99722
# at line 99723
# at line 99724
# at line 99725
# at line 99726
# at line 99727
# at line 99728
# at line 99729
# at line 99730
# at line 99731
# at line 99732
# at line 99733
# at line 99734
# at line 99735
# at line 99736
# at line 99737
# at line 99738
# at line 99739
# at line 99740
# at line 99741
# at line 99742
# at line 99743
# at line 99744
# at line 99745
# at line 99746
# at line 99747
# at line 99748
# at line 99749
# at line 99750
# at line 99751
# at line 99752
# at line 99753
# at line 99754
# at line 99755
# at line 99756
# at line 99757
# at line 99758
# at line 99759
# at line 99760
# at line 99761
# at line 99762
# at line 99763
# at line 99764
# at line 99765
# at line 99766
# at line 99767
# at line 99768
# at line 99769
# at line 99770
# at line 99771
# at line 99772
# at line 99773
# at line 99774
# at line 99775
# at line 99776
# at line 99777
# at line 99778
# at line 99779
# at line 99780
# at line 99781
# at line 99782
# at line 99783
# at line 99784
# at line 99785
# at line 99786
# at line 99787
# at line 99788
# at line 99789
# at line 99790
# at line 99791
# at line 99792
# at line 99793
# at line 99794
# at line 99795
# at line 99796
# at line 99797
# at line 99798
# at line 99799
# at line 99800
# at line 99801
# at line 99802
# at line 99803
# at line 99804
# at line 99805
# at line 99806
# at line 99807
# at line 99808
# at line 99809
# at line 99810
# at line 99811
# at line 99812
# at line 99813
# at line 99814
# at line 99815
# at line 99816
# at line 99817
# at line 99818
# at line 99819
# at line 99820
# at line 99821
# at line 99822
# at line 99823
# at line 99824
# at line 99825
# at line 99826
# at line 99827
# at line 99828
# at line 99829
# at line 99830
# at line 99831
# at line 99832
# at line 99833
# at line 99834
# at line 99835
# at line 99836
# at line 99837
# at line 99838
# at line 99839
# at line 99840
# at line 99841
# at line 99842
# at line 99843
# at line 99844
# at line 99845
# at line 99846
# at line 99847
# at line 99848
# at line 99849
# at line 99850
# at line 99851
# at line 99852
# at line 99853
# at line 99854
# at line 99855
# at line 99856
# at line 99857
# at line 99858
# at line 99859
# at line 99860
# at line 99861
# at line 99862
# at line 99863
# at line 99864
# at line 99865
# at line 99866
# at line 99867
# at line 99868
# at line 99869
# at line 99870
# at line 99871
# at line 99872
# at line 99873
# at line 99874
# at line 99875
# at line 99876
# at line 99877
# at line 99878
# at line 99879
# at line 99880
# at line 99881
# at line 99882
# at line 99883
# at line 99884
# at line 99885
# at line 99886
# at line 99887
# at line 99888
# at line 99889
# at line 99890
# at line 99891
# at line 99892
# at line 99893
# at line 99894
# at line 99895
# at line 99896
# at line 99897
# at line 99898
# at line 99899
# at line 99900
# at line 99901
# at line 99902
# at line 99903
# at line 99904
# at line 99905
# at line 99906
# at line 99907
# at line 99908
# at line 99909
# at line 99910
# at line 99911
# at line 99912
# at line 99913
# at line 99914
# at line 99915
# at line 99916
# at line 99917
# at line 99918
# at line 99919
# at line 99920
# at line 99921
# at line 99922
# at line 99923
# at line 99924
# at line 99925
# at line 99926
# at line 99927
# at line 99928
# at line 99929
# at line 99930
# at line 99931
# at line 99932
# at line 99933
# at line 99934
# at line 99935
# at line 99936
# at line 99937
# at line 99938
# at line 99939
# at line 99940
# at line 99941
# at line 99942
# at line 99943
# at line 99944
# at line 99945
# at line 99946
# at line 99947
# at line 99948
# at line 99949
# at line 99950
# at line 99951
# at line 99952
# at line 99953
# at line 99954
# at line 99955
# at line 99956
# at line 99957
# at line 99958
# at line 99959
# at line 99960
# at line 99961
# at line 99962
# at line 99963
# at line 99964
# at line 99965
# at line 99966
# at line 99967
# at line 99968
# at line 99969
# at line 99970
# at line 99971
# at line 99972
# at line 99973
# at line 99974
# at line 99975
# at line 99976
# at line 99977
# at line 99978
# at line 99979
# at line 99980
# at line 99981
# at line 99982
# at line 99983
# at line 99984
# at line 99985
# at line 99986
# at line 99987
# at line 99988
# at line 99989
# at line 99990
# at line 99991
# at line 99992
# at line 99993
# at line 99994
# at line 99995
# at line 99996
# at line 99997
# at line 99998
# at line 99999
# at line 100000
# finished distance matrix
# generated graph
# Initializing
# IntProgress(value=1, max=50, min=1)
# Passing through generations
# IntProgress(value=1, max=10, min=1)
# fitness: 987692142.8186051, repres: [56273 96945 81240 ... 92103 81133 70490]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
